# %% [markdown]
# <a href="https://colab.research.google.com/github/RodrigoSchneiderbr/Machine_learning/blob/main/capitulo_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
movies = pd.read_csv('movies.csv')
ratings = pd.read_csv('ratings.csv')

# %%
movies.head()
# Out:
#    movieId  ...                                       genres
# 0        1  ...  Adventure|Animation|Children|Comedy|Fantasy
# 1        2  ...                   Adventure|Children|Fantasy
# 2        3  ...                               Comedy|Romance
# 3        4  ...                         Comedy|Drama|Romance
# 4        5  ...                                       Comedy
#
# [5 rows x 3 columns]

# %%
ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
print(movies[movies['movieId']== 50])
# Out:
#     movieId                       title                  genres
# 46       50  Usual Suspects, The (1995)  Crime|Mystery|Thriller

# %%
movie_rating = pd.merge(movies,ratings, on = 'movieId')

# %%
movie_rating.head()
# Out:
#    movieId             title  ... rating   timestamp
# 0        1  Toy Story (1995)  ...    4.0   964982703
# 1        1  Toy Story (1995)  ...    4.0   847434962
# 2        1  Toy Story (1995)  ...    4.5  1106635946
# 3        1  Toy Story (1995)  ...    2.5  1510577970
# 4        1  Toy Story (1995)  ...    4.5  1305696483
#
# [5 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as snr

# %%
movie_rating.groupby('title')['rating'].mean().sort_values(ascending = False).head
# Out:
# <bound method NDFrame.head of title
# Karlson Returns (1970)                           5.0
# Winter in Prostokvashino (1984)                  5.0
# My Love (2006)                                   5.0
# Sorority House Massacre II (1990)                5.0
# Winnie the Pooh and the Day of Concern (1972)    5.0
#                                                 ...
# The Beast of Hollow Mountain (1956)              0.5
# Follow Me, Boys! (1966)                          0.5
# The Butterfly Effect 3: Revelations (2009)       0.5
# The Emoji Movie (2017)                           0.5
# Rust and Bone (De rouille et d'os) (2012)        0.5
# Name: rating, Length: 9719, dtype: float64>

# %%
ratings_2 = pd.DataFrame(movie_rating.groupby('title')['rating'].mean())
ratings_2.sort_values(by='rating', ascending= False).head()
# Out:
#                                      rating
# title
# Gena the Crocodile (1969)               5.0
# True Stories (1986)                     5.0
# Cosmic Scrat-tastrophe (2015)           5.0
# Love and Pigeons (1985)                 5.0
# Red Sorghum (Hong gao liang) (1987)     5.0

# %%
ratings_2['num de avaliação'] = pd.DataFrame(movie_rating.groupby('title')['rating'].count())
ratings_2.sort_values(by ='num de avaliação', ascending = False).head()
# Out:
#                                     rating  num de avaliação
# title
# Forrest Gump (1994)               4.164134               329
# Shawshank Redemption, The (1994)  4.429022               317
# Pulp Fiction (1994)               4.197068               307
# Silence of the Lambs, The (1991)  4.161290               279
# Matrix, The (1999)                4.192446               278

# %%
ratings_2.sort_values(by = 'rating', ascending = False).head()
# Out:
#                                      rating  num de avaliação
# title
# Gena the Crocodile (1969)               5.0                 1
# True Stories (1986)                     5.0                 1
# Cosmic Scrat-tastrophe (2015)           5.0                 1
# Love and Pigeons (1985)                 5.0                 1
# Red Sorghum (Hong gao liang) (1987)     5.0                 1

# %%
ratings_2.boxplot(column='rating')

# %%
plt.figure(figsize = (10,4))
ratings_2['rating'].hist(bins=70)

# %%
movie_rating_matrix = movie_rating.pivot_table(index = 'userId', columns = 'title', values = 'rating')
movie_rating_matrix.tail()
# Out:
# title   '71 (2014)  ...  À nous la liberté (Freedom for Us) (1931)
# userId              ...
# 606            NaN  ...                                        NaN
# 607            NaN  ...                                        NaN
# 608            NaN  ...                                        NaN
# 609            NaN  ...                                        NaN
# 610            4.0  ...                                        NaN
#
# [5 rows x 9719 columns]

# %%
movie_corr_matrix = movie_rating_matrix.corr()
movie_corr_matrix.head()
# Out:
# title                                    '71 (2014)  ...  À nous la liberté (Freedom for Us) (1931)
# title                                                ...
# '71 (2014)                                      NaN  ...                                        NaN
# 'Hellboy': The Seeds of Creation (2004)         NaN  ...                                        NaN
# 'Round Midnight (1986)                          NaN  ...                                        NaN
# 'Salem's Lot (2004)                             NaN  ...                                        NaN
# 'Til There Was You (1997)                       NaN  ...                                        NaN
#
# [5 rows x 9719 columns]

# %%
movie_corr_matrix = movie_rating_matrix.corr(method = 'pearson', min_periods= 50)
movie_corr_matrix.head()
# Out:
# title                                    '71 (2014)  ...  À nous la liberté (Freedom for Us) (1931)
# title                                                ...
# '71 (2014)                                      NaN  ...                                        NaN
# 'Hellboy': The Seeds of Creation (2004)         NaN  ...                                        NaN
# 'Round Midnight (1986)                          NaN  ...                                        NaN
# 'Salem's Lot (2004)                             NaN  ...                                        NaN
# 'Til There Was You (1997)                       NaN  ...                                        NaN
#
# [5 rows x 9719 columns]

# %%
movie_corr_matrix.tail()
# Out:
# title                                      '71 (2014)  ...  À nous la liberté (Freedom for Us) (1931)
# title                                                  ...
# eXistenZ (1999)                                   NaN  ...                                        NaN
# xXx (2002)                                        NaN  ...                                        NaN
# xXx: State of the Union (2005)                    NaN  ...                                        NaN
# ¡Three Amigos! (1986)                             NaN  ...                                        NaN
# À nous la liberté (Freedom for Us) (1931)         NaN  ...                                        NaN
#
# [5 rows x 9719 columns]

# %%
movie_rating_matrix.shape
# Out:
# (610, 9719)

# %%
testuser = movie_rating_matrix.iloc[600].dropna()
testuser.head(10).sort_values(ascending = False)
# Out:
# title
# Band of Brothers (2001)     5.0
# 12 Angry Men (1957)         5.0
# Big Hero 6 (2014)           4.5
# Batman Begins (2005)        4.5
# Avengers, The (2012)        4.5
# Blade Runner 2049 (2017)    4.0
# Beautiful Mind, A (2001)    4.0
# Avatar (2009)               4.0
# Armageddon (1998)           4.0
# 2012 (2009)                 4.0
# Name: 601, dtype: float64

# %%
len(testuser)
# Out:
# 101

# %%
testuser.index[2]
# Out:
# 'Armageddon (1998)'

# %%
testuser[2]
# Out:
# 4.0

# %%
movie_corr_matrix[testuser.index[2]].dropna().sort_values(ascending = False)
# Out:
# title
# Armageddon (1998)                                                                 1.000000
# Independence Day (a.k.a. ID4) (1996)                                              0.665768
# True Lies (1994)                                                                  0.547632
# Star Wars: Episode I - The Phantom Menace (1999)                                  0.457663
# American Pie (1999)                                                               0.430223
# Men in Black (a.k.a. MIB) (1997)                                                  0.424516
# Indiana Jones and the Temple of Doom (1984)                                       0.420462
# Braveheart (1995)                                                                 0.414973
# Saving Private Ryan (1998)                                                        0.409837
# Mission: Impossible (1996)                                                        0.394391
# Speed (1994)                                                                      0.383551
# Die Hard (1988)                                                                   0.381382
# Aladdin (1992)                                                                    0.372129
# X-Men (2000)                                                                      0.369728
# Truman Show, The (1998)                                                           0.369571
# Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)    0.352328
# Titanic (1997)                                                                    0.330931
# Terminator, The (1984)                                                            0.289789
# Forrest Gump (1994)                                                               0.287674
# Shrek (2001)                                                                      0.281484
# Matrix, The (1999)                                                                0.268305
# Usual Suspects, The (1995)                                                        0.261477
# Mask, The (1994)                                                                  0.253037
# Gladiator (2000)                                                                  0.252315
# Jurassic Park (1993)                                                              0.251622
# Silence of the Lambs, The (1991)                                                  0.249055
# Austin Powers: The Spy Who Shagged Me (1999)                                      0.223152
# Terminator 2: Judgment Day (1991)                                                 0.221962
# Seven (a.k.a. Se7en) (1995)                                                       0.201587
# Sixth Sense, The (1999)                                                           0.188845
# Fight Club (1999)                                                                 0.176218
# Star Wars: Episode VI - Return of the Jedi (1983)                                 0.167125
# Indiana Jones and the Last Crusade (1989)                                         0.162807
# Star Wars: Episode IV - A New Hope (1977)                                         0.151674
# Lord of the Rings: The Return of the King, The (2003)                             0.147588
# There's Something About Mary (1998)                                               0.132714
# Shawshank Redemption, The (1994)                                                  0.124737
# Groundhog Day (1993)                                                              0.118994
# Star Wars: Episode V - The Empire Strikes Back (1980)                             0.116660
# Lord of the Rings: The Two Towers, The (2002)                                     0.114761
# Back to the Future (1985)                                                         0.077618
# Pulp Fiction (1994)                                                               0.073534
# Fifth Element, The (1997)                                                         0.049085
# Toy Story (1995)                                                                  0.046408
# American Beauty (1999)                                                            0.036285
# Alien (1979)                                                                      0.021960
# Twelve Monkeys (a.k.a. 12 Monkeys) (1995)                                        -0.021732
# Memento (2000)                                                                   -0.032096
# Lord of the Rings: The Fellowship of the Ring, The (2001)                        -0.035104
# Godfather, The (1972)                                                            -0.080263
# Fargo (1996)                                                                     -0.199108
# Name: Armageddon (1998), dtype: float64

# %%
similarMoviesCandidates = pd.Series()
for i in range(0, len(testuser.index)):
  print('adicionando o filme similar a' + testuser.index[i]+ "...")
  similar = movie_corr_matrix[testuser.index[i]].dropna()
  similar = similar.map(lambda x: x* testuser[i])
  similarMoviesCandidates = similarMoviesCandidates.append(similar)
# Out:
# adicionando o filme similar a12 Angry Men (1957)...
# adicionando o filme similar a2012 (2009)...
# adicionando o filme similar aArmageddon (1998)...
# adicionando o filme similar aAvatar (2009)...
# adicionando o filme similar aAvengers, The (2012)...
# adicionando o filme similar aBand of Brothers (2001)...
# adicionando o filme similar aBatman Begins (2005)...
# adicionando o filme similar aBeautiful Mind, A (2001)...
# adicionando o filme similar aBig Hero 6 (2014)...
# adicionando o filme similar aBlade Runner 2049 (2017)...
# adicionando o filme similar aBourne Ultimatum, The (2007)...
# adicionando o filme similar aBrave (2012)...
# adicionando o filme similar aBug's Life, A (1998)...
# adicionando o filme similar aCasablanca (1942)...
# adicionando o filme similar aCasino Royale (2006)...
# adicionando o filme similar aCatch Me If You Can (2002)...
# adicionando o filme similar aCity of God (Cidade de Deus) (2002)...
# adicionando o filme similar aCoco (2017)...
# adicionando o filme similar aContact (1997)...
# adicionando o filme similar aDark Knight Rises, The (2012)...
# adicionando o filme similar aDeparted, The (2006)...
# adicionando o filme similar aDistrict 9 (2009)...
# adicionando o filme similar aDjango Unchained (2012)...
# adicionando o filme similar aDunkirk (2017)...
# adicionando o filme similar aEasy A (2010)...
# adicionando o filme similar aEternal Sunshine of the Spotless Mind (2004)...
# adicionando o filme similar aFifth Element, The (1997)...
# adicionando o filme similar aFight Club (1999)...
# adicionando o filme similar aFinding Nemo (2003)...
# adicionando o filme similar aGifted (2017)...
# adicionando o filme similar aGirl with the Dragon Tattoo, The (Män som hatar kvinnor) (2009)...
# adicionando o filme similar aGladiator (2000)...
# adicionando o filme similar aGodfather, The (1972)...
# adicionando o filme similar aGodfather: Part II, The (1974)...
# adicionando o filme similar aGone Girl (2014)...
# adicionando o filme similar aGood Will Hunting (1997)...
# adicionando o filme similar aGreat Escape, The (1963)...
# adicionando o filme similar aGuardians of the Galaxy (2014)...
# adicionando o filme similar aGuardians of the Galaxy 2 (2017)...
# adicionando o filme similar aHarry Potter and the Deathly Hallows: Part 1 (2010)...
# adicionando o filme similar aHelp, The (2011)...
# adicionando o filme similar aHow to Train Your Dragon (2010)...
# adicionando o filme similar aHowl's Moving Castle (Hauru no ugoku shiro) (2004)...
# adicionando o filme similar aInception (2010)...
# adicionando o filme similar aIncredibles, The (2004)...
# adicionando o filme similar aInglourious Basterds (2009)...
# adicionando o filme similar aInside Out (2015)...
# adicionando o filme similar aInterstellar (2014)...
# adicionando o filme similar aIron Man (2008)...
# adicionando o filme similar aIt's a Wonderful Life (1946)...
# adicionando o filme similar aKing's Speech, The (2010)...
# adicionando o filme similar aLife Is Beautiful (La Vita è bella) (1997)...
# adicionando o filme similar aLittle Miss Sunshine (2006)...
# adicionando o filme similar aLord of the Rings: The Fellowship of the Ring, The (2001)...
# adicionando o filme similar aLord of the Rings: The Return of the King, The (2003)...
# adicionando o filme similar aLord of the Rings: The Two Towers, The (2002)...
# adicionando o filme similar aMatrix, The (1999)...
# adicionando o filme similar aMemento (2000)...
# adicionando o filme similar aMinority Report (2002)...
# adicionando o filme similar aMonsters, Inc. (2001)...
# adicionando o filme similar aMonty Python and the Holy Grail (1975)...
# adicionando o filme similar aMy Neighbor Totoro (Tonari no Totoro) (1988)...
# adicionando o filme similar aNorth by Northwest (1959)...
# adicionando o filme similar aOcean's Eleven (2001)...
# adicionando o filme similar aOne Flew Over the Cuckoo's Nest (1975)...
# adicionando o filme similar aPan's Labyrinth (Laberinto del fauno, El) (2006)...
# adicionando o filme similar aPrestige, The (2006)...
# adicionando o filme similar aPrincess Bride, The (1987)...
# adicionando o filme similar aPrincess Mononoke (Mononoke-hime) (1997)...
# adicionando o filme similar aRaiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)...
# adicionando o filme similar aRatatouille (2007)...
# adicionando o filme similar aRear Window (1954)...
# adicionando o filme similar aSaving Private Ryan (1998)...
# adicionando o filme similar aSchindler's List (1993)...
# adicionando o filme similar aSeven (a.k.a. Se7en) (1995)...
# adicionando o filme similar aSeven Samurai (Shichinin no samurai) (1954)...
# adicionando o filme similar aShawshank Redemption, The (1994)...
# adicionando o filme similar aShe's Out of My League (2010)...
# adicionando o filme similar aShrek (2001)...
# adicionando o filme similar aShutter Island (2010)...
# adicionando o filme similar aSixth Sense, The (1999)...
# adicionando o filme similar aSlumdog Millionaire (2008)...
# adicionando o filme similar aSocial Network, The (2010)...
# adicionando o filme similar aSpirited Away (Sen to Chihiro no kamikakushi) (2001)...
# adicionando o filme similar aSteve Jobs: The Man in the Machine (2015)...
# adicionando o filme similar aThe Big Sick (2017)...
# adicionando o filme similar aThe Godfather Trilogy: 1972-1990 (1992)...
# adicionando o filme similar aThe Imitation Game (2014)...
# adicionando o filme similar aThor: Ragnarok (2017)...
# adicionando o filme similar aTitanic (1997)...
# adicionando o filme similar aTo Kill a Mockingbird (1962)...
# adicionando o filme similar aToy Story (1995)...
# adicionando o filme similar aToy Story 2 (1999)...
# adicionando o filme similar aToy Story 3 (2010)...
# adicionando o filme similar aUp (2009)...
# adicionando o filme similar aUsual Suspects, The (1995)...
# adicionando o filme similar aV for Vendetta (2006)...
# adicionando o filme similar aWALL·E (2008)...
# adicionando o filme similar aWhiplash (2013)...
# adicionando o filme similar aWolf of Wall Street, The (2013)...
# adicionando o filme similar aZootopia (2016)...
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.

# %%
similarMoviesCandidates.sort_values(inplace = True, ascending = False)
print(similarMoviesCandidates.head(15))
# Out:
# 12 Angry Men (1957)                                          5.0
# Interstellar (2014)                                          5.0
# Ratatouille (2007)                                           5.0
# Princess Bride, The (1987)                                   5.0
# Monsters, Inc. (2001)                                        5.0
# Memento (2000)                                               5.0
# WALL·E (2008)                                                5.0
# Lord of the Rings: The Fellowship of the Ring, The (2001)    5.0
# Lord of the Rings: The Two Towers, The (2002)                5.0
# Lord of the Rings: The Return of the King, The (2003)        5.0
# Usual Suspects, The (1995)                                   5.0
# Rear Window (1954)                                           5.0
# Matrix, The (1999)                                           5.0
# Saving Private Ryan (1998)                                   5.0
# Schindler's List (1993)                                      5.0
# dtype: float64

# %%
similarMoviesCandidates = similarMoviesCandidates.groupby(similarMoviesCandidates.index).sum()
similarMoviesCandidates.sort_values(inplace = True, ascending = False)
similarMoviesCandidates.head(10)
# Out:
# Matrix, The (1999)                                       86.143677
# Inception (2010)                                         85.205182
# Lord of the Rings: The Return of the King, The (2003)    71.533869
# Monsters, Inc. (2001)                                    69.753100
# Saving Private Ryan (1998)                               69.333854
# Finding Nemo (2003)                                      69.224868
# Fight Club (1999)                                        69.197407
# Silence of the Lambs, The (1991)                         66.731743
# Batman Begins (2005)                                     65.728736
# Shawshank Redemption, The (1994)                         64.043923
# dtype: float64

# %%
filtra_movies = similarMoviesCandidates[~similarMoviesCandidates.isin(testuser.index)]
filtra_movies.head(10)
# Out:
# Matrix, The (1999)                                       86.143677
# Inception (2010)                                         85.205182
# Lord of the Rings: The Return of the King, The (2003)    71.533869
# Monsters, Inc. (2001)                                    69.753100
# Saving Private Ryan (1998)                               69.333854
# Finding Nemo (2003)                                      69.224868
# Fight Club (1999)                                        69.197407
# Silence of the Lambs, The (1991)                         66.731743
# Batman Begins (2005)                                     65.728736
# Shawshank Redemption, The (1994)                         64.043923
# dtype: float64

# %%
filme = ['12 Angry Men (1957)']
filme in list(testuser.index)
# Out:
# False

# %%
filtra_movies_recomendados = filtra_movies.sort_values(ascending = True)
filtra_movies_recomendados.head(50)
# Out:
# Waterworld (1995)                                 -1.186821
# Stargate (1994)                                   -1.078114
# Enemy of the State (1998)                         -0.929792
# Ed Wood (1994)                                    -0.805485
# Run Lola Run (Lola rennt) (1998)                  -0.729910
# Close Encounters of the Third Kind (1977)         -0.476667
# X-Men: The Last Stand (2006)                      -0.133232
# Addams Family Values (1993)                       -0.084447
# Die Hard 2 (1990)                                 -0.056932
# Pirates of the Caribbean: At World's End (2007)    0.221290
# No Country for Old Men (2007)                      0.249837
# What's Eating Gilbert Grape (1993)                 0.273704
# Clear and Present Danger (1994)                    0.355742
# Ghost (1990)                                       0.380966
# 40-Year-Old Virgin, The (2005)                     0.426516
# Demolition Man (1993)                              0.472428
# Spaceballs (1987)                                  0.492377
# Mask of Zorro, The (1998)                          0.571781
# Italian Job, The (2003)                            0.680128
# Legends of the Fall (1994)                         0.704446
# Young Frankenstein (1974)                          0.718433
# Sleepy Hollow (1999)                               0.719857
# Amadeus (1984)                                     0.731406
# Star Trek: Generations (1994)                      0.766663
# Gangs of New York (2002)                           0.786722
# Honey, I Shrunk the Kids (1989)                    0.805032
# Lost World: Jurassic Park, The (1997)              0.978772
# Bridget Jones's Diary (2001)                       1.010133
# Dave (1993)                                        1.018735
# Miss Congeniality (2000)                           1.027574
# Untouchables, The (1987)                           1.027793
# Few Good Men, A (1992)                             1.053437
# Gone in 60 Seconds (2000)                          1.118954
# Dogma (1999)                                       1.158825
# Broken Arrow (1996)                                1.161839
# Santa Clause, The (1994)                           1.172560
# Twister (1996)                                     1.224351
# Legally Blonde (2001)                              1.248973
# Con Air (1997)                                     1.301575
# Superman (1978)                                    1.367168
# While You Were Sleeping (1995)                     1.416442
# Charlie and the Chocolate Factory (2005)           1.429711
# Clueless (1995)                                    1.442841
# Sleepless in Seattle (1993)                        1.469775
# Mr. Holland's Opus (1995)                          1.500736
# Wizard of Oz, The (1939)                           1.509885
# Batman Forever (1995)                              1.534629
# Batman Returns (1992)                              1.553379
# I, Robot (2004)                                    1.569087
# Scream (1996)                                      1.580572
# dtype: float64
